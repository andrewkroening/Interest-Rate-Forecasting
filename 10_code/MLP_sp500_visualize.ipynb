# %% [markdown]
# ## MLP Forecaster + S&P500 Viz
#
# Use this notebook to generate the forecast models and appropriate prediction intervals

# %%
# imports
import pandas as pd
import numpy as np
import joblib
import os
import matplotlib.pyplot as plt

from logics_sp500 import plot_forecast, plot_forecast_pct

# %% [markdown]
# ### Visualize the Predictions - Rates

# %%
# read data
df = pd.read_csv("../00_data/clean_data_rates.csv", parse_dates=["Date"])

# set the directory
dir = "../20_intermediate_files/sp500_unlogged_rates_only"

# set the fcast
fcast = ["1 Day", "1 Month", "1 Year", "1 Decade"]

plot_forecast(dir, df, fcast)
# Out:
# here
# ['sp500_rate_forecast_100_1.csv', 'sp500_rate_forecast_504_29.csv', 'sp500_rate_forecast_756_251.csv', 'sp500_rate_forecast_2520_2519.csv']

# %%
# read data
df = pd.read_csv("../00_data/clean_data_rates.csv", parse_dates=["Date"])

# set the directory
dir = "../20_intermediate_files/sp500_logged_rates_only"

# set the fcast
fcast = ["1 Day", "1 Month", "1 Year", "1 Decade"]

plot_forecast(dir, df, fcast)
# Out:
# here
# ['sp500_rate_forecast_100_1.csv', 'sp500_rate_forecast_504_29.csv', 'sp500_rate_forecast_756_251.csv', 'sp500_rate_forecast_2520_2519.csv']
