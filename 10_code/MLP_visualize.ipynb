# %% [markdown]
# ## MLP Forecaster
#
# Use this notebook to generate the forecast models and appropriate prediction intervals

# %%
# imports
import pandas as pd
import numpy as np
import joblib
import os
import matplotlib.pyplot as plt

from logics import plot_forecast, plot_forecast_pct

# %% [markdown]
# ### Visualize the Predictions - Rates

# %%
# read data
df = pd.read_csv("../00_data/clean_data_rates.csv", parse_dates=["Date"])

# set the directory
dir = "../20_intermediate_files/rates_only"

# set the fcast
fcast = ["1 Month - 504", "1 Decade - 2520"]

plot_forecast(dir, df, fcast)

# %%
# read data
df = pd.read_csv("../00_data/clean_data_rates.csv", parse_dates=["Date"])

# set the directory
dir = "../20_intermediate_files/rates_only_backup"

# set the fcast
fcast = ["1 Day - 100", "1 Month - 100", "1 Year - 756", "1 Decade - 1008"]

plot_forecast(dir, df, fcast)

# %% [markdown]
# ### Visualize the Predictions - Pcts

# %%
# read data
df = pd.read_csv("../00_data/clean_data_rates_pct.csv", parse_dates=["Date"])

# set the directory
dir = "../20_intermediate_files/rates_pct"

# set the fcast
fcast = ["1 Month - 504", "1 Decade - 1008"]

plot_forecast_pct(dir, df, fcast)

# %%
# read data
df = pd.read_csv("../00_data/clean_data_rates_pct.csv", parse_dates=["Date"])

# set the directory
dir = "../20_intermediate_files/rates_pct_backup"

# set the fcast
fcast = ["1 Day - 100", "1 Month - 100", "1 Year - 756", "1 Decade - 2520"]

plot_forecast_pct(dir, df, fcast)

# %% [markdown]
# ### Visualize the Predictions - Diffs

# %%
# read data
df = pd.read_csv("../00_data/clean_data_rates_diff.csv", parse_dates=["Date"])

# set the directory
dir = "../20_intermediate_files/rates_diff"

# set the fcast
fcast = ["1 Month - 504", "1 Decade - 1008"]

plot_forecast_pct(dir, df, fcast)

# %%
# read data
df = pd.read_csv("../00_data/clean_data_rates_diff.csv", parse_dates=["Date"])

# set the directory
dir = "../20_intermediate_files/rates_diff_backup"

# set the fcast
fcast = ["1 Day - 100", "1 Month - 100", "1 Year - 756", "1 Decade - 2520"]

plot_forecast_pct(dir, df, fcast)
